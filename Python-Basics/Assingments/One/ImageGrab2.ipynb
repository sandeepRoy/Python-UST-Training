# %%
import requests
import bs4

response_data = requests.get('https://unsplash.com/photos/g28AEKvS3wg')

# %%
soup = bs4.BeautifulSoup(response_data.text, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
image_info = soup.select('.YVj9w')
image_info
# Out:
# [<img alt="aerial photograph of sea wave splashing on rock" class="YVj9w" sizes="(max-width: 767px) 100vw, (max-width: 419px) min(100%, 387px), (max-height: 786px) min(100%, 387px), (min-aspect-ratio: 3648/5472) calc((calc(100vh - 205px)) * 0.666667), calc(100vw - 32px)" src="https://images.unsplash.com/photo-1502433075460-fbfac3f0db4c?ixlib=rb-1.2.1&amp;ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&amp;auto=format&amp;fit=crop&amp;w=1000&amp;q=80" srcset="https://images.unsplash.com/photo-1502433075460-fbfac3f0db4c?ixlib=rb-1.2.1&amp;ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&amp;auto=format&amp;fit=crop&amp;w=387&amp;q=80 387w, https://images.unsplash.com/photo-1502433075460-fbfac3f0db4c?ixlib=rb-1.2.1&amp;ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&amp;auto=format&amp;fit=crop&amp;w=687&amp;q=80 687w, https://images.unsplash.com/photo-1502433075460-fbfac3f0db4c?ixlib=rb-1.2.1&amp;ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&amp;auto=format&amp;fit=crop&amp;w=
# ...

# %%
len(image_info)
# Out:
# 2

# %%
image_info[0]
# Out:
# <img alt="aerial photograph of sea wave splashing on rock" class="YVj9w" sizes="(max-width: 767px) 100vw, (max-width: 419px) min(100%, 387px), (max-height: 786px) min(100%, 387px), (min-aspect-ratio: 3648/5472) calc((calc(100vh - 205px)) * 0.666667), calc(100vw - 32px)" src="https://images.unsplash.com/photo-1502433075460-fbfac3f0db4c?ixlib=rb-1.2.1&amp;ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&amp;auto=format&amp;fit=crop&amp;w=1000&amp;q=80" srcset="https://images.unsplash.com/photo-1502433075460-fbfac3f0db4c?ixlib=rb-1.2.1&amp;ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&amp;auto=format&amp;fit=crop&amp;w=387&amp;q=80 387w, https://images.unsplash.com/photo-1502433075460-fbfac3f0db4c?ixlib=rb-1.2.1&amp;ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&amp;auto=format&amp;fit=crop&amp;w=687&amp;q=80 687w, https://images.unsplash.com/photo-1502433075460-fbfac3f0db4c?ixlib=rb-1.2.1&amp;ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&amp;auto=format&amp;fit=crop&amp;w=7
# ...

# %%
image_to_save = image_info[0]

# %%
image_to_save['src']
# Out:
# 'https://images.unsplash.com/photo-1502433075460-fbfac3f0db4c?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=1000&q=80'

# %%
link_to_image = requests.get('https://images.unsplash.com/photo-1502433075460-fbfac3f0db4c?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=1000&q=80')

# %%
link_to_image.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xe2\x0cXICC_PROFILE\x00\x01\x01\x00\x00\x0cHLino\x02\x10\x00\x00mntrRGB XYZ \x07\xce\x00\x02\x00\t\x00\x06\x001\x00\x00acspMSFT\x00\x00\x00\x00IEC sRGB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-HP  \x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x11cprt\x00\x00\x01P\x00\x00\x003desc\x00\x00\x01\x84\x00\x00\x00lwtpt\x00\x00\x01\xf0\x00\x00\x00\x14bkpt\x00\x00\x02\x04\x00\x00\x00\x14rXYZ\x00\x00\x02\x18\x00\x00\x00\x14gXYZ\x00\x00\x02,\x00\x00\x00\x14bXYZ\x00\x00\x02@\x00\x00\x00\x14dmnd\x00\x00\x02T\x00\x00\x00pdmdd\x00\x00\x02\xc4\x00\x00\x00\x88vued\x00\x00\x03L\x00\x00\x00\x86view\x00\x00\x03\xd4\x00\x00\x00$lumi\x00\x00\x03\xf8\x00\x00\x00\x14meas\x00\x00\x04\x0c\x00\x00\x00$tech\x00\x00\x040\x00\x00\x00\x0crTRC\x00\x00\x04<\
# ...

# %%
save_data = open('Sea_Shore.jpg', 'wb')

# %%
save_data.write(link_to_image.content)
# Out:
# 503949

# %%
save_data.close()

# %% [markdown]
# <img src = 'Sea_Shore.jpg'>
